# %% [markdown]
# <a href="https://colab.research.google.com/github/drm1072/Data_Sets/blob/main/Data_Science_Basics_with_python_part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #Used for high level Data Indexing processes
import numpy as np  #Numpy provides fast mathematical function processing
# importing libraries pandas as pd/numpy as np

# %%
NEWDATASAMPLE = pd.read_csv("https://raw.githubusercontent.com/drm1072/Data_Sets/main/freeformResponses.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5,17,21,38,50) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#This code gives you the size of your dataframe (rows and columns)
#The 1st number is the nubmer of rows(atributes) and the 2nd number is the number of colums(features)
NEWDATASAMPLE.shape
# Out:
# (16716, 62)

# %%
#When you add a number it shows us more of the data set relative to that number
# The head function gives u a preview of the data
NEWDATASAMPLE.head(7)
# Out:
#   GenderFreeForm  ... JobSearchResourceFreeForm
# 0            NaN  ...                       NaN
# 1            NaN  ...                       NaN
# 2            NaN  ...                       NaN
# 3            NaN  ...                       NaN
# 4            NaN  ...                       NaN
# 5            NaN  ...                       NaN
# 6            NaN  ...                       NaN
#
# [7 rows x 62 columns]

# %%
#When you add tail function it gives us the last 5 data sets
NEWDATASAMPLE.tail()
# Out:
#       GenderFreeForm  ... JobSearchResourceFreeForm
# 16711            NaN  ...                       NaN
# 16712            NaN  ...                       NaN
# 16713            NaN  ...                       NaN
# 16714            NaN  ...                       NaN
# 16715            NaN  ...                       NaN
#
# [5 rows x 62 columns]

# %%
NEWDATASAMPLE.tail(8)
# Out:
#       GenderFreeForm  ... JobSearchResourceFreeForm
# 16708            NaN  ...                       NaN
# 16709            NaN  ...                       NaN
# 16710            NaN  ...                       NaN
# 16711            NaN  ...                       NaN
# 16712            NaN  ...                       NaN
# 16713            NaN  ...                       NaN
# 16714            NaN  ...                       NaN
# 16715            NaN  ...                       NaN
#
# [8 rows x 62 columns]

# %%
NEWDATASAMPLE
# This code gives us the 1st 5 rows and last 5 rows of data same (when the variable is put in by itself)
# Out:
#       GenderFreeForm  ... JobSearchResourceFreeForm
# 0                NaN  ...                       NaN
# 1                NaN  ...                       NaN
# 2                NaN  ...                       NaN
# 3                NaN  ...                       NaN
# 4                NaN  ...                       NaN
# ...              ...  ...                       ...
# 16711            NaN  ...                       NaN
# 16712            NaN  ...                       NaN
# 16713            NaN  ...                       NaN
# 16714            NaN  ...                       NaN
# 16715            NaN  ...                       NaN
#
# [16716 rows x 62 columns]

# %%
NEWDATASAMPLE.fillna("")
# .fillna removes all of Nan values
# Out:
#       GenderFreeForm  ... JobSearchResourceFreeForm
# 0                     ...
# 1                     ...
# 2                     ...
# 3                     ...
# 4                     ...
# ...              ...  ...                       ...
# 16711                 ...
# 16712                 ...
# 16713                 ...
# 16714                 ...
# 16715                 ...
#
# [16716 rows x 62 columns]

# %%
#This code removes NAN values
NEWDATASAMPLE2=NEWDATASAMPLE.fillna("")

# %%
NEWDATASAMPLE2
# Create a new variable helps when adding to variable
# saving your work by creating a new variable
# Out:
#       GenderFreeForm  ... JobSearchResourceFreeForm
# 0                     ...
# 1                     ...
# 2                     ...
# 3                     ...
# 4                     ...
# ...              ...  ...                       ...
# 16711                 ...
# 16712                 ...
# 16713                 ...
# 16714                 ...
# 16715                 ...
#
# [16716 rows x 62 columns]

# %%
#I want to dig in the data a little more (maximum amount of rows)
#I have added this code to see all of the data. instead of the preview, it gives me up to 17000 rows because my dataframe is 16,716
pd.options.display.max_rows = 17000

# %%
pd.options.display.max_rows
# Out:
# 17000

# %%
NEWDATASAMPLE2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-ee24b401b71c> in <module>()
# ----> 1 NEWDATASAMPLE2
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/displayhook.py in __call__(self, result)
#     244             self.start_displayhook()
#     245             self.write_output_prompt()
# --> 246             format_dict, md_dict = self.compute_format_data(result)
#     247             self.update_user_ns(result)
#     248             self.fill_exec_result(result)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     148
#     149         """
# --> 150         return self.shell.display_formatter.format(result)
#     151
#     152     # This can be set to True by the write_output_prompt method in a subclass
#
# ...

# %%
#Now lets change it back so we can move faster through our data
pd.options.display.max_rows = 100

# %%
NEWDATASAMPLE2
# Out:
#       GenderFreeForm  ... JobSearchResourceFreeForm
# 0                     ...
# 1                     ...
# 2                     ...
# 3                     ...
# 4                     ...
# ...              ...  ...                       ...
# 16711                 ...
# 16712                 ...
# 16713                 ...
# 16714                 ...
# 16715                 ...
#
# [16716 rows x 62 columns]

# %%
#This command Gives a list of Column names
NEWDATASAMPLE2.columns.values
# Out:
# array(['GenderFreeForm', 'KaggleMotivationFreeForm',
#        'CurrentJobTitleFreeForm', 'MLToolNextYearFreeForm',
#        'MLMethodNextYearFreeForm', 'LanguageRecommendationFreeForm',
#        'PublicDatasetsFreeForm', 'PersonalProjectsChallengeFreeForm',
#        'LearningPlatformCommunityFreeForm', 'LearningPlatformFreeForm1',
#        'LearningPlatformFreeForm2', 'LearningPlatformFreeForm3',
#        'LearningPlatformUsefulnessCommunitiesFreeForm',
#        'LearningPlatformUsefulnessFreeForm1Select',
#        'LearningPlatformUsefulnessFreeForm1SelectFreeForm',
#        'LearningPlatformUsefulnessFreeForm2Select',
#        'LearningPlatformUsefulnessFreeForm2SelectFreeForm',
#        'LearningPlatformUsefulnessFreeForm3Select',
#        'LearningPlatformUsefulnessFreeForm3SelectFreeForm',
#        'BlogsPodcastsNewslettersFreeForm',
#        'JobSkillImportanceOtherSelect1FreeForm',
#        'JobSkillImportanceOtherSelect2FreeForm',
# ...

# %%
#dtype shows us the data type of each column (integer, object, float, and etc)
#object- is a collection of data
#object is data that is mixed with numbers and text valves
NEWDATASAMPLE2.dtypes
# Out:
# GenderFreeForm                                       object
# KaggleMotivationFreeForm                             object
# CurrentJobTitleFreeForm                              object
# MLToolNextYearFreeForm                               object
# MLMethodNextYearFreeForm                             object
# LanguageRecommendationFreeForm                       object
# PublicDatasetsFreeForm                               object
# PersonalProjectsChallengeFreeForm                    object
# LearningPlatformCommunityFreeForm                    object
# LearningPlatformFreeForm1                            object
# LearningPlatformFreeForm2                            object
# LearningPlatformFreeForm3                            object
# LearningPlatformUsefulnessCommunitiesFreeForm        object
# LearningPlatformUsefulnessFreeForm1Select            object
# LearningPlatformUsefulnessFreeForm1SelectFreeForm    object
# LearningPlatformUsefulnessFreeForm2Select            object
# ...

# %%
#astype Converts entire dataframe to strings, when we dont see or need numerical values
NEWDATASAMPLE2= NEWDATASAMPLE2.astype('string')

# %%
#Now we have successfully turned all of the values within our columns into strings.
NEWDATASAMPLE2.dtypes
# Out:
# GenderFreeForm                                       string
# KaggleMotivationFreeForm                             string
# CurrentJobTitleFreeForm                              string
# MLToolNextYearFreeForm                               string
# MLMethodNextYearFreeForm                             string
# LanguageRecommendationFreeForm                       string
# PublicDatasetsFreeForm                               string
# PersonalProjectsChallengeFreeForm                    string
# LearningPlatformCommunityFreeForm                    string
# LearningPlatformFreeForm1                            string
# LearningPlatformFreeForm2                            string
# LearningPlatformFreeForm3                            string
# LearningPlatformUsefulnessCommunitiesFreeForm        string
# LearningPlatformUsefulnessFreeForm1Select            string
# LearningPlatformUsefulnessFreeForm1SelectFreeForm    string
# LearningPlatformUsefulnessFreeForm2Select            string
# ...

# %%
#Lets do some quick data analysis within a column
# This breaks down the value of the data (sorts the data)
#This gives us the value count of each value within our column-Column(career names)
NEWDATASAMPLE2["CurrentJobTitleFreeForm"].value_counts()
# Out:
#                         15573
# Project Manager            27
# Professor                  23
# Consultant                 22
# Actuary                    20
#                         ...
# telemetry                   1
# Technical Support           1
# risk specialist             1
# Company consultant          1
# Ti Business Analyst         1
# Name: CurrentJobTitleFreeForm, Length: 765, dtype: Int64

# %%
#Lets delete a column of data we feel is unimportant
#del is delete
del NEWDATASAMPLE2['GenderFreeForm']

# %%
#This command makes everything lower case.
NEWDATASAMPLE2["CurrentJobTitleFreeForm"] = NEWDATASAMPLE2["CurrentJobTitleFreeForm"].str.lower()

# %%
#This command removes non-text characters.
NEWDATASAMPLE2['PersonalProjectsChallengeFreeForm'] = NEWDATASAMPLE2['PersonalProjectsChallengeFreeForm'].str.replace(r'\.|\!|\?|\'|,|-|\(|\)', "",)

# %%
#This command renames some columns
NEWDATASAMPLE2.rename(columns={'CurrentJobTitleFreeForm': 'Careers', 'CoursePlatformFreeForm': 'Course', 'LearningPlatformFreeForm1':'Learning Platforms'},inplace=True)

# %%
NEWDATASAMPLE3=NEWDATASAMPLE2

# %%
NEWDATASAMPLE3
# Out:
#       KaggleMotivationFreeForm  ... JobSearchResourceFreeForm
# 0                               ...
# 1                               ...
# 2                               ...
# 3                               ...
# 4                               ...
# ...                        ...  ...                       ...
# 16711                           ...
# 16712                           ...
# 16713                           ...
# 16714                           ...
# 16715                           ...
#
# [16716 rows x 61 columns]

# %%
import base64
from IPython.display import HTML

def create_download_link( df3, title = "Download CSV file", filename = "Structured.csv"):
    csv = NEWDATASAMPLE2.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a'
    html = html.format(payload=payload, title=title, filename=filename)
    return HTML(html)

create_download_link(NEWDATASAMPLE2)
# Out:
# <a download="Structured.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a
